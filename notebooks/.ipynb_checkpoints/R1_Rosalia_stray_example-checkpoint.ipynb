# %%
# This notebook demonstrates how to use ROSALIA to analyze stray light in a simple exposure. 
import os 
import sys 
sys.path.append("/Users/aborlaff/NASA/ROSALIA/")

import rosalia as rs
from astropy.time import Time
# Out:
# Some IP addresses of users launching heavy query showers have temporarily been disabled. Please contact the Gaia helpdesk (https://www.cosmos.esa.int/web/gaia/gaia-helpdesk) for advice. Workaround solutions for the Gaia Archive issues following the infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive

# %%
sys.path
# Out:
# ['/Users/aborlaff/GIT/adsabs-dev-api',
#  '/Users/aborlaff/GIT/asta',
#  '/Users/aborlaff/GIT/astrobox',
#  '/Users/aborlaff/GIT/Bootima',
#  '/Users/aborlaff/GIT/bootmedian',
#  '/Users/aborlaff/GIT/bootmedian copy',
#  '/Users/aborlaff/GIT/CIAO',
#  '/Users/aborlaff/GIT/de440.bsp',
#  '/Users/aborlaff/GIT/ds9.command',
#  '/Users/aborlaff/GIT/GIMP-2.10.app',
#  '/Users/aborlaff/GIT/gunagala',
#  '/Users/aborlaff/GIT/healpy',
#  '/Users/aborlaff/GIT/output.pdf',
#  '/Users/aborlaff/GIT/pylira',
#  '/Users/aborlaff/GIT/python-skyfield',
#  '/Users/aborlaff/GIT/rmath',
#  '/Users/aborlaff/GIT/roman_gc_pointing',
#  '/Users/aborlaff/GIT/romanisim',
#  '/Users/aborlaff/GIT/SAOImageDS9.app',
#  '/Users/aborlaff/GIT/tinytim-7.5',
#  '/Users/aborlaff/NASA/ROSALIA/notebooks',
#  '/Users/aborlaff/NASA/SPARKLES',
#  '/Users/aborlaff/NASA/FIRE/code/pfh_python',
#  '/Users/aborlaff/miniforge3/envs/rosalia/lib/python312.zip',
#  '/Users/aborlaff/miniforge3/envs/rosalia/lib/python3.12',
#  '/Users/aborlaff/miniforge3/envs/rosalia/lib/python3.12/lib-dynload',
#  '',
#  '/Users/aborlaff/miniforge3/envs/rosalia/lib/python3.12/site-packages',
#  '/Users/aborlaff/NASA/ROSALIA/']

# %%
rs.__file__
# Out:
# '/Users/aborlaff/miniforge3/envs/rosalia/lib/python3.12/site-packages/rosalia/__init__.py'

# %%
# Let's define the minimum parameters to generate a dummy Roman / WFI image
ra = 123 # Right ascension, in degrees. 
dec = 23 # Declination, in degrees.
PA = 125 # Position angle, in degrees.
date = Time("2024-06-01T00:00:00") # Date of the observation, in Astropy Time YYYY-MM-DDTHH:MM:SS format.
bandpass = "F129"
exptime = 600 # Exposure time, in seconds.

# %%
rosalia_stray = rs.correct.rosalia_stray(ra=ra, dec=dec, 
                                         PA=PA, date=date, bandpass=bandpass, 
                                         exptime=exptime, radius=1,
                                         g_mag_max=15, sun_block=False, verbose=False, catalog=None)

# %%
rosalia_stray
