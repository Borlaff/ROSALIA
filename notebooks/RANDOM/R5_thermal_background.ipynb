# %%
def rst_wfi_thermal_background(exptime):
    """
    Returns the thermal background for Roman

    WARNING: This is a placeholder version with a constant thermal flux. 
    Future versions will estimate this as a function of other parameters, 
    including, but not restricted to, solar distance angle and solar roll angle. 

    :param exptime:
    :type exptime: :class:`np.ndarray` or float in degrees
    :return: thermal_back :array: A (18,)-sized array containing the thermal background in e-/px/s on Roman / WFI SCAs 1 -- 18. 
    """

    thermal_background = np.array([0.22, 0.17, 0.15, 0.23, 0.21, 0.19,
                                   0.26, 0.23, 0.22, 0.22, 0.17, 0.17,
                                   0.23, 0.20, 0.18, 0.26, 0.24, 0.24])

    return(thermal_background)
