# %%
import pandas as pd
hp_db = pd.read_csv("/Users/aborlaff/NASA/STRAYCOR/straycor/CORE/gaia_2mass_wise_healpix_7_cat.csv")
hp_db["ra"] = hp_db["ra"].astype('float32')
hp_db["dec"] = hp_db["dec"].astype('float32')
hp_db["wise_ra"] = hp_db["wise_ra"].astype('float32')
hp_db["wise_dec"] = hp_db["wise_dec"].astype('float32')
hp_db["tmass_ra"] = hp_db["tmass_ra"].astype('float32')
hp_db["tmass_dec"] = hp_db["tmass_dec"].astype('float32')
hp_db["phot_bp_mean_mag"] = hp_db["phot_bp_mean_mag"].astype('float32')
hp_db["phot_g_mean_mag"] = hp_db["phot_g_mean_mag"].astype('float32')
hp_db["phot_rp_mean_mag"] = hp_db["phot_rp_mean_mag"].astype('float32')
hp_db["parallax"] = hp_db["parallax"].astype('float32')

hp_db["w1"] = hp_db["w1"].astype('float32')
hp_db["w1_error"] = hp_db["w1_error"].astype('float32')
hp_db["w2"] = hp_db["w2"].astype('float32')
hp_db["w2_error"] = hp_db["w2_error"].astype('float32')
hp_db["w3"] = hp_db["w3"].astype('float32')
hp_db["w3_error"] = hp_db["w3_error"].astype('float32')
hp_db["w4"] = hp_db["w4"].astype('float32')
hp_db["w4_error"] = hp_db["w4_error"].astype('float32')

hp_db["j"] = hp_db["j"].astype('float32')
hp_db["j_error"] = hp_db["j_error"].astype('float32')
hp_db["h"] = hp_db["h"].astype('float32')
hp_db["h_error"] = hp_db["h_error"].astype('float32')
hp_db["ks"] = hp_db["ks"].astype('float32')
hp_db["ks_error"] = hp_db["ks_error"].astype('float32')
hp_db["g"] = hp_db["g"].astype('float32')
hp_db["bp"] = hp_db["bp"].astype('float32')
hp_db["rp"] = hp_db["rp"].astype('float32')

hp_db["phot_g_mean_mag_AB"] = hp_db["phot_g_mean_mag_AB"].astype('float32')
hp_db["phot_bp_mean_mag_AB"] = hp_db["phot_bp_mean_mag_AB"].astype('float32')
hp_db["phot_rp_mean_mag_AB"] = hp_db["phot_rp_mean_mag_AB"].astype('float32')
hp_db["phot_j_mean_mag_AB"] = hp_db["phot_j_mean_mag_AB"].astype('float32')
hp_db["phot_h_mean_mag_AB"] = hp_db["phot_h_mean_mag_AB"].astype('float32')
hp_db["phot_ks_mean_mag_AB"] = hp_db["phot_ks_mean_mag_AB"].astype('float32')
hp_db["phot_w1_mean_mag_AB"] = hp_db["phot_w1_mean_mag_AB"].astype('float32')
hp_db["phot_w2_mean_mag_AB"] = hp_db["phot_w2_mean_mag_AB"].astype('float32')
hp_db["phot_w3_mean_mag_AB"] = hp_db["phot_w3_mean_mag_AB"].astype('float32')
hp_db["phot_w4_mean_mag_AB"] = hp_db["phot_w4_mean_mag_AB"].astype('float32')

hp_db.to_csv("/Users/aborlaff/NASA/ROSALIA/rosalia/CORE/gaia_2mass_wise_healpix_7_cat.csv")
