# %%
import rosalia as rs
from astropy.time import Time
from astropy.coordinates import SkyCoord  # High-level coordinates
import astropy.units as u

# %%
rs.roman.create_roman_dummy(point=SkyCoord(1, -30, frame="icrs", unit="deg"),
                            date=Time(61000, format='mjd'), 
                            band="F213", 
                            PA=45, 
                            exptime=500, 
                            output="default_roman_dummy.fits")
# Out:
# 'default_roman_dummy.fits'
