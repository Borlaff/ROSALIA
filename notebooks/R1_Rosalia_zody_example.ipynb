# %%
# This notebook demonstrates how to use ROSALIA to measure the expected zodiacal background in a simple image. 
import rosalia as rs
from astropy.time import Time
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/matplotlib/style/core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/matplotlib/__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/matplotlib/__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/aborlaff/NASA/rosalia_cache//CORE/presi_style.mplstyle'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 2
#       1 # This notebook demonstrates how to use ROSALIA to measure the expected zodiacal background in a simple image.
# ----> 2 import rosalia as rs
#       3 from astropy.time import Time
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/rosalia/__init__.py:22
#      20 import rosalia.mast
#      21 import rosalia.ndi
# ---> 22 import rosalia.psf
#      23 import rosalia.gaia
#      24 import rosalia.gnu
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/rosalia/psf.py:40
#      32 # Custom modules
#      33 #sys.path.append("/Users/aborlaff/NASA/STRAYCOR/")
#      34
#      35
#      36 # STRAYCOR modules
#      39 psf_archive = os.environ["ROSALIACACHE"] + "/CORE/PSF_ARCHIVE/"
# ---> 40 plt.style.use(os.environ["ROSALIACACHE"]+ "/CORE/presi_style.mplstyle")
#      43 def scale_and_subtract_stars(input_name, ext, exposure_identity, g_mag_max=False, clean=False, verbose=False):
#      44     ## TODO: Compute the scale factor for the object at (x,y)=(53,69) for
#      45     ## the PSF (psf.fits). Compute it in the ring 20-30 pixels.
#    (...)     57
#      58     # Exposure identity properties
#      59     lambda_ref = exposure_identity["FILTER_IDENTITY"]["filter_lambda_ref"]
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/matplotlib/style/core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: '/Users/aborlaff/NASA/rosalia_cache//CORE/presi_style.mplstyle' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
ra = 123 # Right ascension, in degrees. 
dec = 45 # Declination, in degrees.
PA = 67 # Position angle, in degrees.
date = Time("2026-10-01T00:00:00") # Date of the observation, in Astropy Time YYYY-MM-DDTHH:MM:SS format.
bandpass = "F129"
exptime = 600 # Exposure time, in seconds.

rosalia_zody = rs.correct.rosalia_zody(ra=ra, dec=dec, PA=PA, date=date, 
                                     bandpass=bandpass, exptime=exptime,
                                     g_mag_max=15, verbose=False)
