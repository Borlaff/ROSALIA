# %%
import os
import glob 
import rosalia as rs
# Out:
# SPARKLES v1.0.0
# ROSALIA v0.8.0

# %%
input_pattern = "/Users/aborlaff/NASA/ROSALIA/notebooks/DEVEL/RST_WFI_ROSALIA_ra200_dec-23_test_SCAwfi0[1-2].asdf"

# %%
rs.utils.convert_ASDF_to_FITS(asdf_list=glob.glob(input_pattern), output="test.fits")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.91it/s]
# 'test.fits'

# %%
rs.correct.rosalia_zody(input_name="test.fits", output_name="test_rosalia_zody_output.fits")
# Out:
#   0%|                                                                                                | 0/2 [00:00<?, ?it/s]
# DEMO WARNING: Zodipy is configured at the center of Earth. Fix that!
#  50%|████████████████████████████████████████████                                            | 1/2 [00:05<00:05,  5.26s/it]
# DEMO WARNING: Zodipy is configured at the center of Earth. Fix that!
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:10<00:00,  5.24s/it]
# 2it [00:00, 1031.43it/s]
# Output saved in: test_rosalia_zody_output.fits
# {'image_identity': {'FILENAME': 'test.fits',
#   'TELESCOP': 'ROMAN',
#   'INSTRUME': 'WFI',
#   'DETECTOR': 'WFI',
#   'EXPSTART': 61041.0,
#   'EXPEND': 61041.001477777776,
#   'EXPTIME': 127.68,
#   'EXPSTART_ISOT': '2026-01-01T00:00:00.000',
#   'PA': 0.0,
#   'SCA': [1, 2],
#   'HST_TYPE': 'GEN',
#   'FILTER': 'F158',
#   'FILTER_IDENTITY': {'filter_id': 'Roman/WFI.F158',
#    'filter_transmission_curve': <Table length=107>
#    Wavelength Transmission
#        AA          m2
#     float64     float64
#    ---------- ------------
#       13200.0       0.0003
#       13250.0       0.0009
#       13300.0       0.0028
#       13350.0       0.0076
#       13400.0       0.0189
#       13450.0        0.043
#       13500.0       0.0901
#       13550.0       0.1733
#       13600.0       0.3074
#           ...          ...
#       18100.0       0.1238
#       18150.0       0.0721
#       18200.0       0.0399
#       18250.0        0.021
#       18300.0       0.0105
#       18350.0       0.0049
#       18400.0       0.0022
#       18450.0       0.0009
#       18500.0       0.0004,
#    'filter_lambda_ref': <Quantity 15577.82822333 Angstrom>,
#    'filter_lambda_min': <Quantity 13500. Angstrom>,
#    'filter_lambda_max': <Quantity 18150. Angstrom>,
#    'filter_lambda_width': <Quantity 3546.71997516 Angstrom>,
#    'filter_transmission_ref': array(2.90423485),
#    'wavelength': Unit("F158 Angstrom"),
#    'telescope': 'ROMAN',
#    'instrument': 'WFI',
#    'detector': 'WFI'},
#   'PHYSPIX': <Quantity 1.e-05 m>,
#   'PIXSCALE': <Quantity 0.11 arcsec>,
#   'SCIEXTS': [1, 2],
#   'DATA': [array([[ 7.1335888e-01, -5.2813586e-02,  5.0037217e-01, ...,
#            -8.1005916e-03,  7.0171255e-01, -6.2700175e-03],
#           [ 5.6578934e-01,  6.2331587e-01,  6.3367116e-01, ...,
#             8.5116577e+02,  6.3142186e-01,  1.8105017e+03],
#           [ 6.5814883e-01,  5.4723531e-01,  5.5637157e-01, ...,
#            -3.9923787e-02,  5.5152589e-01,  2.6062196e-03],
#           ...,
#           [ 6.2181526e-01,  6.3172251e-01,  6.9211853e-01, ...,
#             7.0951414e-01,  7.0261085e-01,  6.5313703e-01],
#           [ 7.0363009e-01,  7.1147192e-01,  6.0592413e-01, ...,
#             5.5955333e-01,  6.6220164e-01,  6.1961609e-01],
#           [ 7.3736274e-01,  7.4485725e-01,  6.3592947e-01, ...,
#             6.9511425e-01,  5.0256962e-01,  6.0041904e-01]], dtype='>f4'),
#    array([[ 5.4768264e-01,  6.3239539e-01,  5.2335793e-01, ...,
#             5.1755713e+03,  4.2180631e-01,  4.6260068e+03],
#           [ 6.3154697e-01,  5.6857127e-01,  5.2411759e-01, ...,
#            -4.5802803e+03,  6.2272412e-01,  4.1095630e+03],
#           [ 4.8581448e-01,  5.3975427e-01,  5.5812651e-01, ...,
#            -3.3155444e+02,  4.8765463e-01, -4.0784656e+02],
#           ...,
#           [ 5.1492000e-01,  6.2803811e-01,  5.6275195e-01, ...,
#             6.1279869e-01,  6.7400348e-01,  6.0334665e-01],
#           [ 6.8354803e-01,  5.8106178e-01,  6.5633905e-01, ...,
#             6.1151212e-01,  5.8560687e-01,  4.5834726e-01],
#           [ 5.6557548e-01,  6.5828454e-01,  6.3952696e-01, ...,
#             6.5429819e-01,  5.2073252e-01,  5.9296775e-01]], dtype='>f4')],
#   'ASTROPYWCS': [WCS Keywords
#
#    Number of WCS axes: 2
#    CTYPE : 'RA---TAN' 'DEC--TAN'
#    CRVAL : 199.92612188016 -22.964382498584
#    CRPIX : 2044.5 2044.5
#    PC1_1 PC1_2  : -3.0651065396462e-05 -7.955507651632e-08
#    PC2_1 PC2_2  : 1.0260134284071e-07 3.007736612826e-05
#    CDELT : 1.0 1.0
#    NAXIS : 4088  4088,
#    WCS Keywords
#
#    Number of WCS axes: 2
#    CTYPE : 'RA---TAN' 'DEC--TAN'
#    CRVAL : 199.92612750486 -23.110750765387
#    CRPIX : 2044.5 2044.5
#    PC1_1 PC1_2  : -3.0426364287534e-05 -1.0675431649363e-07
#    PC2_1 PC2_2  : 1.3063008962193e-07 2.9423974576014e-05
#    CDELT : 1.0 1.0
#    NAXIS : 4088  4088],
#   'RA_PNT': 199.9261530037,
#   'DEC_PNT': -23.0369129649,
#   'X_PNT': 2187.5,
#   'Y_PNT': 4677.0,
#   'FILETYPE': 'FITS'},
#  'zodi_list': array([[5.89039923e-06, 5.89039190e-06, 5.89038456e-06, ...,
#          5.86195663e-06, 5.86195029e-06, 5.86194395e-06],
#         [5.89040229e-06, 5.89039496e-06, 5.89038764e-06, ...,
#          5.86195850e-06, 5.86195216e-06, 5.86194582e-06],
#         [5.89040535e-06, 5.89039801e-06, 5.89039071e-06, ...,
#          5.86196036e-06, 5.86195402e-06, 5.86194769e-06],
#         ...,
#         [5.90000189e-06, 5.89999524e-06, 5.89998859e-06, ...,
#          5.87152673e-06, 5.87151927e-06, 5.87151179e-06],
#         [5.90000483e-06, 5.89999819e-06, 5.89999153e-06, ...,
#          5.87152890e-06, 5.87152143e-06, 5.87151396e-06],
#         [5.90000778e-06, 5.90000113e-06, 5.89999448e-06, ...,
#          5.87153109e-06, 5.87152360e-06, 5.87151612e-06]]),
#  'output_name': 'test_rosalia_zody_output.fits'}

# %%
import numpy as np
mu = -2.5*np.log10(np.array(zodiacal_background_list[1])) + 8.9

# %%
import matplotlib.pyplot as plt
plt.imshow(mu)
plt.colorbar()

# %%
zodiacal_background_list[0]
