# %%
import rosalia as rs
import numpy as np
import glob
import os
from astropy.io import fits
import pandas as pd 
from tqdm import tqdm
# Out:
# ROSALIA v0.9.0

# %%
# Make the average of all the NDI files at 1 deg

deg1_ndi_old = glob.glob("/Users/aborlaff/NASA/ROSALIA/rosalia/CORE/NDI/RST/ndi_lvl1/lvl1*.fits")
deg1_ndi_fits_canvas = fits.open(deg1_ndi_old[0])

canvas = np.zeros(deg1_ndi_fits_canvas[0].data.shape)

for i in tqdm(range(len(deg1_ndi_old))):
    deg1_ndi_i = fits.open(deg1_ndi_old[i])
    canvas = canvas + deg1_ndi_i[0].data

canvas = canvas / len(deg1_ndi_old)
deg1_ndi_fits_canvas[0].data = canvas
deg1_ndi_fits_canvas.verify("silentfix")
deg1_ndi_fits_canvas.writeto("/Users/aborlaff/NASA/ROSALIA_DEPOT/1_deg_average_NDI.fits", overwrite=True)
# Out:
# 100%|███████████████████████████████████████████████████████████| 1152/1152 [00:35<00:00, 32.57it/s]

# %%
# Make the average of all the NDI files at 20 deg
"""
deg20_ndi_old = glob.glob("/Users/aborlaff/NASA/ROSALIA/rosalia/CORE/NDI/RST/20-deg*.fits")
deg20_ndi_fits_canvas = fits.open(deg20_ndi_old[0])

canvas = np.zeros(deg20_ndi_fits_canvas[0].data.shape)

for i in range(len(deg20_ndi_old)):
    deg20_ndi_i = fits.open(deg20_ndi_old[i])
    canvas = canvas + deg20_ndi_i[0].data

canvas = canvas / len(deg20_ndi_old)
deg20_ndi_fits_canvas[0].data = canvas
deg20_ndi_fits_canvas.verify("silentfix")
deg20_ndi_fits_canvas.writeto("/Users/aborlaff/NASA/ROSALIA_DEPOT/20_deg_average_NDI_old.fits", overwrite=True)
"""
# Out:
# '\ndeg20_ndi_old = glob.glob("/Users/aborlaff/NASA/ROSALIA/rosalia/CORE/NDI/RST/20-deg*.fits")\ndeg20_ndi_fits_canvas = fits.open(deg20_ndi_old[0])\n\ncanvas = np.zeros(deg20_ndi_fits_canvas[0].data.shape)\n\nfor i in range(len(deg20_ndi_old)):\n    deg20_ndi_i = fits.open(deg20_ndi_old[i])\n    canvas = canvas + deg20_ndi_i[0].data\n\ncanvas = canvas / len(deg20_ndi_old)\ndeg20_ndi_fits_canvas[0].data = canvas\ndeg20_ndi_fits_canvas.verify("silentfix")\ndeg20_ndi_fits_canvas.writeto("/Users/aborlaff/NASA/ROSALIA_DEPOT/20_deg_average_NDI_old.fits", overwrite=True)\n'

# %%
# Make the average of all the NDI files at All sky deg
allsky_ndi_old = glob.glob("/Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl3/lvl3_SCA*[0-9].fits")
allsky_ndi_fits_canvas = fits.open(allsky_ndi_old[0])

import bottleneck as bn 

canvas = np.zeros((allsky_ndi_fits_canvas[0].data.shape[0], allsky_ndi_fits_canvas[0].data.shape[1], 18))

for i in range(len(allsky_ndi_old)):
    allsky_ndi_i = fits.open(allsky_ndi_old[i])
    canvas[:,:,i] = allsky_ndi_i[0].data

canvas = bn.nanmean(canvas, axis=2)
allsky_ndi_fits_canvas[0].data = canvas
allsky_ndi_fits_canvas.verify("silentfix")
allsky_ndi_fits_canvas.writeto("/Users/aborlaff/NASA/ROSALIA_DEPOT/allsky_average_NDI_old.fits", overwrite=True)

# %%
# Make a smooth background from the first level optics NDI (without the FPA lightshield!). 

"""
csmooth "2-deg at 5 arcsec SCA 1.fits" outfile="NDI_back_2deg_lvl1_SCA_1.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 2.fits" outfile="NDI_back_2deg_lvl1_SCA_2.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 3.fits" outfile="NDI_back_2deg_lvl1_SCA_3.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 4.fits" outfile="NDI_back_2deg_lvl1_SCA_4.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 5.fits" outfile="NDI_back_2deg_lvl1_SCA_5.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 6.fits" outfile="NDI_back_2deg_lvl1_SCA_6.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 7.fits" outfile="NDI_back_2deg_lvl1_SCA_7.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 8.fits" outfile="NDI_back_2deg_lvl1_SCA_8.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 9.fits" outfile="NDI_back_2deg_lvl1_SCA_9.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 10.fits" outfile="NDI_back_2deg_lvl1_SCA_10.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 11.fits" outfile="NDI_back_2deg_lvl1_SCA_11.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 12.fits" outfile="NDI_back_2deg_lvl1_SCA_12.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 13.fits" outfile="NDI_back_2deg_lvl1_SCA_13.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 14.fits" outfile="NDI_back_2deg_lvl1_SCA_14.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 15.fits" outfile="NDI_back_2deg_lvl1_SCA_15.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 16.fits" outfile="NDI_back_2deg_lvl1_SCA_16.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 17.fits" outfile="NDI_back_2deg_lvl1_SCA_17.fits" clobber=yes
csmooth "2-deg at 5 arcsec SCA 18.fits" outfile="NDI_back_2deg_lvl1_SCA_18.fits" clobber=yes

"""
# Out:
# '\ncsmooth "2-deg at 5 arcsec SCA 1.fits" outfile="NDI_back_2deg_lvl1_SCA_1.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 2.fits" outfile="NDI_back_2deg_lvl1_SCA_2.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 3.fits" outfile="NDI_back_2deg_lvl1_SCA_3.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 4.fits" outfile="NDI_back_2deg_lvl1_SCA_4.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 5.fits" outfile="NDI_back_2deg_lvl1_SCA_5.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 6.fits" outfile="NDI_back_2deg_lvl1_SCA_6.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 7.fits" outfile="NDI_back_2deg_lvl1_SCA_7.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 8.fits" outfile="NDI_back_2deg_lvl1_SCA_8.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 9.fits" outfile="NDI_back_2deg_lvl1_SCA_9.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 10.fits" outfile="NDI_back_2deg_lvl1_SCA_10.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 11.fits" outfile="NDI_back_2deg_lvl1_SCA_11.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 12.fits" outfile="NDI_back_2deg_lvl1_SCA_12.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 13.fits" outfile="NDI_back_2deg_lvl1_SCA_13.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 14.fits" outfile="NDI_back_2deg_lvl1_SCA_14.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 15.fits" outfile="NDI_back_2deg_lvl1_SCA_15.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 16.fits" outfile="NDI_back_2deg_lvl1_SCA_16.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 17.fits" outfile="NDI_back_2deg_lvl1_SCA_17.fits" clobber=yes\ncsmooth "2-deg at 5 arcsec SCA 18.fits" outfile="NDI_back_2deg_lvl1_SCA_18.fits" clobber=yes\n\n'

# %%
# Make the level 1, level 2 and level 3 NDI files. 

"""
# Level 1
# Step 1 - Open the first open (FPA holders)
# Step 2 - Open the additional layer for the lightshields. 

"""
subarray_locations_db = rs.roman.get_subarray_locations(SCA=1, verbose=False)
SCA_list = np.linspace(1,18,18, dtype="int")

ndi_prefix = "lvl1"
output_list = []

for SCA_i in SCA_list:
    # print(SCA_i)
    for label_index in range(len(subarray_locations_db["xlabel"])):

        # Get the labels 
        xlabel = subarray_locations_db["xlabel"][label_index]
        ylabel = subarray_locations_db["ylabel"][label_index]

        # Find the right original files
        NDI_base_file = glob.glob("/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/*SCA " + str(SCA_i) + " " + str(xlabel) + " " + str(ylabel) + ".fits")
        NDI_lightshield_extra_file = glob.glob("/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/*SCA " + str(SCA_i) + " " + str(xlabel) + " " + str(ylabel) + ".fits")
        NDI_background = glob.glob("/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back*SCA_" + str(SCA_i)+ ".fits")
        
        print(NDI_base_file)
        print(NDI_lightshield_extra_file)
        print(NDI_background)

        
        NDI_fits = fits.open(NDI_base_file[0])
        NDI_lightshield_fits = fits.open(NDI_lightshield_extra_file[0])
        NDI_background_fits = fits.open(NDI_background[0])

        NDI_fits[0].data = NDI_fits[0].data + NDI_lightshield_fits[0].data + NDI_background_fits[0].data
        
        new_name = "/Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/" + ndi_prefix + "_SCA_" + str(SCA_i)+ "_SUB_X" + str(xlabel) + "_Y" + str(ylabel) + ".fits"
        # cmd = "cp '" + NDI_file[0] + "' " + new_name
        print(new_name)


        #### Now, make a custom WCS for this file, based on the angular size that they spand. 
        cdelt = [-(NDI_fits[0].header["AAXISMAX"] - NDI_fits[0].header["AAXISMIN"])/NDI_fits[0].header["NAXIS1"], 
                  (NDI_fits[0].header["BAXISMAX"] - NDI_fits[0].header["BAXISMIN"])/NDI_fits[0].header["NAXIS2"]]

        crpix = [(NDI_fits[0].header["NAXIS1"])/2, (NDI_fits[0].header["NAXIS2"])/2]
        SCA_subarray_location = pd.read_csv("/Users/aborlaff/NASA/ROSALIA/rosalia/CORE/detector/RST_WFI_SCA_Subarray_locations.csv")
        crval_X = np.array(SCA_subarray_location["Field X"])[(SCA_subarray_location["SCA"] == SCA_i) & (SCA_subarray_location["SCAx"] == xlabel) & (SCA_subarray_location["SCAy"] == ylabel)][0]
        crval_Y = np.array(SCA_subarray_location["Field Y"])[(SCA_subarray_location["SCA"] == SCA_i) & (SCA_subarray_location["SCAx"] == xlabel) & (SCA_subarray_location["SCAy"] == ylabel)][0]
 
        """
        subpos1, subpos2 = find_subposition_EXTNAME(EXTNAME=NDI_fits_cube[i].header["EXTNAME"]) 
        SCA = find_SCA_EXTNAME(EXTNAME=NDI_fits_cube[i].header["EXTNAME"])
        output_name = NDI_fits_cube_name.replace(".fits", "_SUB_X" + str(subpos1).zfill(2) + "_Y" + str(subpos2).zfill(2) + ".fits").replace(" ","_")

        NDI_i_data = NDI_fits_cube[i].data 
        NDI_i_header = NDI_fits_cube[i].header
        crpix = [(NDI_fits_cube[0].header["NAXIS1"])/2, (NDI_fits_cube[0].header["NAXIS2"])/2]
        # Here, we have to use the subarray location table to put CRVAL to the real location in degrees.
        SCA_subarray_location = pd.read_csv("/Users/aborlaff/NASA/STRAYCOR/straycor/CORE/detector/RST_WFI_SCA_Subarray_locations.csv")
        crval_X = np.array(SCA_subarray_location["Field X"])[(SCA_subarray_location["SCA"] == SCA) & (SCA_subarray_location["SCAx"] == subpos1) & (SCA_subarray_location["SCAy"] == subpos2)][0]
        crval_Y = np.array(SCA_subarray_location["Field Y"])[(SCA_subarray_location["SCA"] == SCA) & (SCA_subarray_location["SCAx"] == subpos1) & (SCA_subarray_location["SCAy"] == subpos2)][0]

        """
        crval = [0, 0] # [crval_X, -crval_Y] # I think that this has to be 0, 0 
        cdelt = [cdelt[0], cdelt[1]        ]
        header = rs.utils.create_custom_wcs(crpix=crpix, crval=crval, cdelt=cdelt, projection="CAR")

        header["AAXISMAX"] = (NDI_fits[0].header["AAXISMAX"])
        header["AAXISMIN"] = (NDI_fits[0].header["AAXISMIN"])
        header["BAXISMAX"] = (NDI_fits[0].header["BAXISMAX"])
        header["BAXISMIN"] = (NDI_fits[0].header["BAXISMIN"])
        header["SUBPOSX"] = xlabel
        header["SUBPOSY"] = ylabel
        header["EXTNAME"] = NDI_fits[0].header["EXTNAME"]

        #print(NDI_i_header)
        rs.utils.save_fits(array=NDI_fits[0].data, name=new_name, header=header)
        output_list.append(new_name)
        
        #NDI_fits.verify("silentfix")
        #NDI_fits.writeto(new_name, overwrite=True)
# Out:
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -17.92 -17.92.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -17.92 -17.92.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-17.92_Y-17.92.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -17.92 -12.8.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -17.92 -12.8.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-17.92_Y-12.8.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -17.92 -7.68.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -17.92 -7.68.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-17.92_Y-7.68.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -17.92 -2.56.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -17.92 -2.56.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-17.92_Y-2.56.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -17.92 2.56.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -17.92 2.56.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-17.92_Y2.56.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -17.92 7.68.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -17.92 7.68.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-17.92_Y7.68.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -17.92 12.8.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -17.92 12.8.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-17.92_Y12.8.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -17.92 17.92.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -17.92 17.92.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-17.92_Y17.92.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -12.8 -17.92.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -12.8 -17.92.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-12.8_Y-17.92.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -12.8 -12.8.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -12.8 -12.8.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-12.8_Y-12.8.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -12.8 -7.68.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -12.8 -7.68.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-12.8_Y-7.68.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -12.8 -2.56.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -12.8 -2.56.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_SCA_1_SUB_X-12.8_Y-2.56.fits
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_FPA_base/2-deg at 5 arcsec SCA 1 -12.8 2.56.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_light_shields/2-deg at 5 arcsec SCA 1 -12.8 2.56.fits']
# ['/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/2-deg_at_5_arcsec/NDI_back_2deg_lvl1_SCA_1.fits']
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3381, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3377 exec_count = self.execution_count
#    3378 if result.error_in_exec:
#    3379     # Store formatted traceback and error details
#    3380     self.history_manager.exceptions[exec_count] = (
# -> 3381         self._format_exception_for_storage(result.error_in_exec)
#    3382     )
#    3384 # Each cell is a *single* input, regardless of how many lines it has
#    3385 self.execution_count += 1
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3435, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3432         stb = evalue._render_traceback_()
#    3433     else:
#    3434         # Otherwise, use InteractiveTB to format the traceback.
# -> 3435         stb = self.InteractiveTB.structured_traceback(
#    3436             etype, evalue, tb, tb_offset=1
#    3437         )
#    3438 except Exception:
#    3439     # In case formatting fails, fallback to Python's built-in formatting.
#    3440     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/IPython/core/ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/IPython/core/ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/IPython/core/ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/IPython/core/ultratb.py:773, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     763         frames.append(
#     764             theme_table[self._theme_name].format(
#     765                 [
#    (...)    770             )
#     771         )
#     772         skipped = 0
# --> 773     frames.append(self.format_record(record))
#     774 if skipped:
#     775     frames.append(
#     776         theme_table[self._theme_name].format(
#     777             [
#    (...)    782         )
#     783     )
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/IPython/core/ultratb.py:651, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
# --> 651     _format_traceback_lines(
#     652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/IPython/core/tbtools.py:99, in _format_traceback_lines(lines, theme, has_colors, lvals_toks)
#      96     continue
#      98 lineno = stack_line.lineno
# ---> 99 line = stack_line.render(pygmented=has_colors).rstrip("\n") + "\n"
#     100 if stack_line.is_current:
#     101     # This is the line with the error
#     102     pad = numbers_width - len(str(lineno))
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/stack_data/core.py:391, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     389 if pygmented and self.frame_info.scope:
#     390     assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 391     start_line, lines = self.frame_info._pygmented_scope_lines
#     392     result = lines[self.lineno - start_line]
#     393     if strip_leading_indent:
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/stack_data/core.py:824, in FrameInfo._pygmented_scope_lines(self)
#     821     ranges = []
#     823 code = atext.get_text(scope)
# --> 824 lines = _pygmented_with_ranges(formatter, code, ranges)
#     826 start_line = self.source.line_range(scope)[0]
#     828 return start_line, lines
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/stack_data/utils.py:166, in _pygmented_with_ranges(formatter, code, ranges)
#     164 lexer = MyLexer(stripnl=False)
#     165 try:
# --> 166     highlighted = pygments.highlight(code, lexer, formatter)
#     167 except Exception:
#     168     # When pygments fails, prefer code without highlighting over crashing
#     169     highlighted = code
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/pygments/__init__.py:82, in highlight(code, lexer, formatter, outfile)
#      77 def highlight(code, lexer, formatter, outfile=None):
#      78     """
#      79     This is the most high-level highlighting function. It combines `lex` and
#      80     `format` in one function.
#      81     """
# ---> 82     return format(lex(code, lexer), formatter, outfile)
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/pygments/__init__.py:64, in format(tokens, formatter, outfile)
#      62 if not outfile:
#      63     realoutfile = getattr(formatter, 'encoding', None) and BytesIO() or StringIO()
# ---> 64     formatter.format(tokens, realoutfile)
#      65     return realoutfile.getvalue()
#      66 else:
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/pygments/formatters/terminal256.py:250, in Terminal256Formatter.format(self, tokensource, outfile)
#     249 def format(self, tokensource, outfile):
# --> 250     return Formatter.format(self, tokensource, outfile)
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/pygments/formatter.py:124, in Formatter.format(self, tokensource, outfile)
#     121 if self.encoding:
#     122     # wrap the outfile in a StreamWriter
#     123     outfile = codecs.lookup(self.encoding)[3](outfile)
# --> 124 return self.format_unencoded(tokensource, outfile)
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/pygments/formatters/terminal256.py:261, in Terminal256Formatter.format_unencoded(self, tokensource, outfile)
#     258 while ttype and not_found:
#     259     try:
#     260         # outfile.write( "<" + str(ttype) + ">" )
# --> 261         on, off = self.style_string[str(ttype)]
#     263         # Like TerminalFormatter, add "reset colors" escape sequence
#     264         # on newline.
#     265         spl = value.split('\n')
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/pygments/token.py:43, in _TokenType.__repr__(self)
#      40     new.parent = self
#      41     return new
# ---> 43 def __repr__(self):
#      44     return 'Token' + (self and '.' or '') + '.'.join(self)
#      46 def __copy__(self):
#      47     # These instances are supposed to be singletons
#
# KeyboardInterrupt:

# %%
# Reproject them to a TAN projection map. 
rs.utils.create_dummy_image_with_wcs(ra_cen=0, dec_cen=0, ra_size=2, dec_size=2, pixscale=5/60/60, outname="default_dummy.fits")

os.system("rm /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1*_TAN.fits")
lvl1_maps = glob.glob("/Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl1/lvl1_*.fits")

from reproject import reproject_interp
from tqdm import tqdm 

footprint_dummy = fits.open("default_dummy.fits")

for lvl1_map_i in tqdm(lvl1_maps): 
    lvl1_map_i_fits = fits.open(lvl1_map_i)
    array, footprint = reproject_interp(lvl1_map_i_fits[0], footprint_dummy[0].header)
    #footprint_dummy[0].data = array 
    lvl1_map_i_fits[0].data = array
    lvl1_map_i_fits[0].header = footprint_dummy[0].header
    lvl1_map_i_fits.verify("silentfix")
    lvl1_map_i_fits.writeto(lvl1_map_i.replace(".fits", "_TAN.fits"), overwrite=True)

# %%
# Make the level 2

"""
# Level 2
# Step 1 - Open the first open (FPA holders)
# Step 2 - Open the additional layer for the lightshields. 

"""

# Make the level 1, level 2 and level 3 NDI files. 

"""
# Level 1
# Step 1 - Open the first open (FPA holders)
# Step 2 - Open the additional layer for the lightshields. 

"""
subarray_locations_db = rs.roman.get_subarray_locations(SCA=1, verbose=False)
SCA_list = np.linspace(1,18,18, dtype="int")

ndi_prefix = "lvl2"
output_list = []

for SCA_i in SCA_list:
    # print(SCA_i)
    if True:
        
        # Get the labels 
        xlabel = subarray_locations_db["xlabel"][label_index]
        ylabel = subarray_locations_db["ylabel"][label_index]

        # Find the right original files
        NDI_base_file = glob.glob("/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/20-deg at 1 arcmin SCA 1/20-deg at 1 arcmin SCA " + str(SCA_i) + ".fits")
        
        print(NDI_base_file)
        
        NDI_fits = fits.open(NDI_base_file[0])
        
        new_name = "/Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl2/" + ndi_prefix + "_SCA_" + str(SCA_i)+ ".fits"

        print(new_name)


        #### Now, make a custom WCS for this file, based on the angular size that they spand. 
        cdelt = [-(NDI_fits[0].header["AAXISMAX"] - NDI_fits[0].header["AAXISMIN"])/NDI_fits[0].header["NAXIS1"], 
                  (NDI_fits[0].header["BAXISMAX"] - NDI_fits[0].header["BAXISMIN"])/NDI_fits[0].header["NAXIS2"]]

        crpix = [(NDI_fits[0].header["NAXIS1"])/2, (NDI_fits[0].header["NAXIS2"])/2]
        SCA_subarray_location = pd.read_csv("/Users/aborlaff/NASA/ROSALIA/rosalia/CORE/detector/RST_WFI_SCA_Subarray_locations.csv")
        crval_X = np.mean(np.array(SCA_subarray_location["Field X"])[(SCA_subarray_location["SCA"] == SCA_i)])
        crval_Y = np.mean(np.array(SCA_subarray_location["Field Y"])[(SCA_subarray_location["SCA"] == SCA_i)])

        print(crval_X)
        print(crval_Y)
        """
        subpos1, subpos2 = find_subposition_EXTNAME(EXTNAME=NDI_fits_cube[i].header["EXTNAME"]) 
        SCA = find_SCA_EXTNAME(EXTNAME=NDI_fits_cube[i].header["EXTNAME"])
        output_name = NDI_fits_cube_name.replace(".fits", "_SUB_X" + str(subpos1).zfill(2) + "_Y" + str(subpos2).zfill(2) + ".fits").replace(" ","_")



        

        NDI_i_data = NDI_fits_cube[i].data 
        NDI_i_header = NDI_fits_cube[i].header
        crpix = [(NDI_fits_cube[0].header["NAXIS1"])/2, (NDI_fits_cube[0].header["NAXIS2"])/2]
        # Here, we have to use the subarray location table to put CRVAL to the real location in degrees.
        SCA_subarray_location = pd.read_csv("/Users/aborlaff/NASA/STRAYCOR/straycor/CORE/detector/RST_WFI_SCA_Subarray_locations.csv")
        crval_X = np.array(SCA_subarray_location["Field X"])[(SCA_subarray_location["SCA"] == SCA) & (SCA_subarray_location["SCAx"] == subpos1) & (SCA_subarray_location["SCAy"] == subpos2)][0]
        crval_Y = np.array(SCA_subarray_location["Field Y"])[(SCA_subarray_location["SCA"] == SCA) & (SCA_subarray_location["SCAx"] == subpos1) & (SCA_subarray_location["SCAy"] == subpos2)][0]

        """
        #crval = [crval_X, -crval_Y]
        crval = [0, 0] # [crval_X, -crval_Y] # I think that this has to be 0, 0 
        
        cdelt = [cdelt[0], cdelt[1]        ]
        header = rs.utils.create_custom_wcs(crpix=crpix, crval=crval, cdelt=cdelt, projection="CAR")

        header["AAXISMAX"] = (NDI_fits[0].header["AAXISMAX"])
        header["AAXISMIN"] = (NDI_fits[0].header["AAXISMIN"])
        header["BAXISMAX"] = (NDI_fits[0].header["BAXISMAX"])
        header["BAXISMIN"] = (NDI_fits[0].header["BAXISMIN"])
        header["SUBPOSX"] = xlabel
        header["SUBPOSY"] = ylabel
        header["EXTNAME"] = NDI_fits[0].header["EXTNAME"]

        #print(NDI_i_header)
        rs.utils.save_fits(array=NDI_fits[0].data, name=new_name, header=header)
        output_list.append(new_name)
        
        #NDI_fits.verify("silentfix")
        #NDI_fits.writeto(new_name, overwrite=True)

# %%
# Reproject them to a TAN projection map. 
rs.utils.create_dummy_image_with_wcs(ra_cen=0, dec_cen=0, ra_size=21, dec_size=21, pixscale=1/60, outname="default_dummy.fits")

os.system("rm /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl2/lvl2*_TAN.fits")
lvl1_maps = glob.glob("/Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl2/lvl2_*.fits")

from reproject import reproject_interp
from tqdm import tqdm 

footprint_dummy = fits.open("default_dummy.fits")

for lvl2_map_i in tqdm(lvl2_maps): 
    lvl2_map_i_fits = fits.open(lvl2_map_i)
    array, footprint = reproject_interp(lvl2_map_i_fits[0], footprint_dummy[0].header)
    #footprint_dummy[0].data = array 
    lvl2_map_i_fits[0].data = array
    lvl2_map_i_fits[0].header = footprint_dummy[0].header
    lvl2_map_i_fits.verify("silentfix")
    lvl2_map_i_fits.writeto(lvl2_map_i.replace(".fits", "_TAN.fits"), overwrite=True)

# %%
# Make the level 3

"""
# Level 2
# Step 1 - Open the first open (FPA holders)
# Step 2 - Open the additional layer for the lightshields. 

"""


subarray_locations_db = rs.roman.get_subarray_locations(SCA=1, verbose=False)
SCA_list = np.linspace(1,18,18, dtype="int")

ndi_prefix = "lvl3"
output_list = []

for SCA_i in SCA_list:
    # print(SCA_i)
    if True:
        
        # Get the labels 
        xlabel = subarray_locations_db["xlabel"][label_index]
        ylabel = subarray_locations_db["ylabel"][label_index]

        # Find the right original files
        NDI_base_file = glob.glob("/Users/aborlaff/NASA/ROSALIA_DEPOT/SCOTT_SIMS_Jan2025_1st_order/All sky at 0.25 deg SCA 1/All sky at 0.25 deg SCA " + str(SCA_i) + ".fits")
        
        print(NDI_base_file)
        
        NDI_fits = fits.open(NDI_base_file[0])
        
        new_name = "/Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl3/" + ndi_prefix + "_SCA_" + str(SCA_i)+ ".fits"

        print(new_name)


        #### Now, make a custom WCS for this file, based on the angular size that they spand. 
        cdelt = [-(NDI_fits[0].header["AAXISMAX"] - NDI_fits[0].header["AAXISMIN"])/NDI_fits[0].header["NAXIS1"], 
                  (NDI_fits[0].header["BAXISMAX"] - NDI_fits[0].header["BAXISMIN"])/NDI_fits[0].header["NAXIS2"]]

        crpix = [(NDI_fits[0].header["NAXIS1"])/2, (NDI_fits[0].header["NAXIS2"])/2]
        SCA_subarray_location = pd.read_csv("/Users/aborlaff/NASA/ROSALIA/rosalia/CORE/detector/RST_WFI_SCA_Subarray_locations.csv")
        crval_X = np.mean(np.array(SCA_subarray_location["Field X"])[(SCA_subarray_location["SCA"] == SCA_i)])
        crval_Y = np.mean(np.array(SCA_subarray_location["Field Y"])[(SCA_subarray_location["SCA"] == SCA_i)])

        print(crval_X)
        print(crval_Y)
        """
        subpos1, subpos2 = find_subposition_EXTNAME(EXTNAME=NDI_fits_cube[i].header["EXTNAME"]) 
        SCA = find_SCA_EXTNAME(EXTNAME=NDI_fits_cube[i].header["EXTNAME"])
        output_name = NDI_fits_cube_name.replace(".fits", "_SUB_X" + str(subpos1).zfill(2) + "_Y" + str(subpos2).zfill(2) + ".fits").replace(" ","_")



        

        NDI_i_data = NDI_fits_cube[i].data 
        NDI_i_header = NDI_fits_cube[i].header
        crpix = [(NDI_fits_cube[0].header["NAXIS1"])/2, (NDI_fits_cube[0].header["NAXIS2"])/2]
        # Here, we have to use the subarray location table to put CRVAL to the real location in degrees.
        SCA_subarray_location = pd.read_csv("/Users/aborlaff/NASA/STRAYCOR/straycor/CORE/detector/RST_WFI_SCA_Subarray_locations.csv")
        crval_X = np.array(SCA_subarray_location["Field X"])[(SCA_subarray_location["SCA"] == SCA) & (SCA_subarray_location["SCAx"] == subpos1) & (SCA_subarray_location["SCAy"] == subpos2)][0]
        crval_Y = np.array(SCA_subarray_location["Field Y"])[(SCA_subarray_location["SCA"] == SCA) & (SCA_subarray_location["SCAx"] == subpos1) & (SCA_subarray_location["SCAy"] == subpos2)][0]

        """
        # crval = [crval_X, -crval_Y]
        crval = [0, 0] # [crval_X, -crval_Y] # I think that this has to be 0, 0 
        cdelt = [cdelt[0], cdelt[1]        ]
        header = rs.utils.create_custom_wcs(crpix=crpix, crval=crval, cdelt=cdelt, projection="CAR")

        header["AAXISMAX"] = (NDI_fits[0].header["AAXISMAX"])
        header["AAXISMIN"] = (NDI_fits[0].header["AAXISMIN"])
        header["BAXISMAX"] = (NDI_fits[0].header["BAXISMAX"])
        header["BAXISMIN"] = (NDI_fits[0].header["BAXISMIN"])
        header["SUBPOSX"] = xlabel
        header["SUBPOSY"] = ylabel
        header["EXTNAME"] = NDI_fits[0].header["EXTNAME"]

        #print(NDI_i_header)
        rs.utils.save_fits(array=NDI_fits[0].data, name=new_name, header=header)
        output_list.append(new_name)
        
        #NDI_fits.verify("silentfix")
        #NDI_fits.writeto(new_name, overwrite=True)

# %%
# Reproject them to a TAN projection map. 
os.system("rm /Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl3/lvl3*_HP.fits")
lvl3_maps = glob.glob("/Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl3/lvl3_*.fits")

from reproject import reproject_interp
from tqdm import tqdm 
import reproject

for lvl3_map_i in tqdm(lvl3_maps): 
    m = reproject.reproject_to_healpix(input_data=lvl3_map_i, coord_system_out='icrs', hdu_in=0, order='bilinear', nested=False, nside=256)
    m = np.array(m)
    m[np.isnan(m)] = 0
    hp.fitsfunc.write_map(filename=lvl3_map_i.replace(".fits", "_HP.fits"), m=m, nest=False, overwrite=True)

# %%
import astropy.wcs as astropy_wcs

projection = "HPX"
if True:
    w = astropy_wcs.WCS(naxis=2)

    # What is the center pixel of the XY grid.
    w.wcs.crpix = crpix

    # what is the galactic coordinate of that pixel.
    w.wcs.crval = crval

    # what is the pixel scale in lon, lat.
    # This essentially modifies how apparently large is the galaxy. Tweak it at your desire.
    w.wcs.cdelt = cdelt
    w.wcs.crota = [0,0]

    # you would have to determine if this is in fact a tangential projection.
    w.wcs.ctype = ["RA---"+projection, "DEC--"+projection]

    # write the HDU object WITH THE HEADER
    header = w.to_header()

    rs.utils.save_fits(array=NDI_fits[0].data, name=new_name.replace(".fits", "_"+projection+".fits"), header=header)

# %%
# Test to make an empty healpix all sky map
import healpy as hp

# %%
NSIDE = 32
print(
    "Approximate resolution at NSIDE {} is {:.2} deg".format(
        NSIDE, hp.nside2resol(NSIDE, arcmin=True) / 60
    )
)
NPIX = hp.nside2npix(NSIDE)
print(NPIX)

m = np.arange(NPIX)
hp.mollview(m, title="Mollview image RING")
hp.graticule()


hp.fitsfunc.write_map(filename="test_hp.fits", m=m, nest=False)

# %%
import reproject
m = reproject.reproject_to_healpix(input_data="/Users/aborlaff/NASA/ROSALIA_DEPOT/ndi_lvl3/lvl3_SCA_1.fits", coord_system_out='icrs', hdu_in=0, order='bilinear', nested=False, nside=128)
hp.fitsfunc.write_map(filename="test_hp.fits", m=m, nest=False, overwrite=True)

# %%
## Healpix calculations. 
# Optimal resolution for all the maps 
# lvl 1  2-deg at 5 arcsec SCA  -  0.0833 arcmin   ------ NSIDE 1024
# lvl 2  20-deg at 1 arcmin SCA  - 1 arcmin  ------ NSIDE 64
# lvl 3. All sky at 0.25 deg SCA 1  - 15 arcmin

import healpy as hp
hp.nside2resol(2**8, arcmin = True)

# %%
2**8

# %%
2**11
