# %%
import rosalia as rs
from astropy.time import Time
# Out:
# Warning: the passwords of all user accounts have been inactivated.              Please visit https://cas.cosmos.esa.int/cas/passwd to set a new one. Workaround solutions for the Gaia Archive issues following the infrastructure upgrade: https://www.cosmos.esa.int/web/gaia/news#WorkaroundArchive

# %%
# This notebook demonstrates how to use ROSALIA to analyze psf in a simple image. 
# We will create a simple image, and then we will use ROSALIA to model the PSF in the image.

# %%
ra = 123 # Right ascension, in degrees. 
dec = 23 # Declination, in degrees.
PA = 45 # Position angle, in degrees.
date = Time("2024-06-01T00:00:00") # Date of the observation, in Astropy Time YYYY-MM-DDTHH:MM:SS format.
bandpass = "F129"
exptime = 600 # Exposure time, in seconds.

rosalia_psf = rs.correct.rosalia_psf(ra=ra, dec=dec, PA=PA, date=date, 
                                     bandpass=bandpass, exptime=exptime,
                                     g_mag_max=15, verbose=False)
# Out:
# /Users/aborlaff/NASA/ROSALIA/notebooks/WFI_F129_RA_123.000_DEC_023.000_MJD_60462.00000_PA_045.00.fits
# 2026-02-23 14:27:10 INFO     Retrieving tables...
# INFO: Retrieving tables... [astroquery.utils.tap.core]
# 2026-02-23 14:27:13 INFO     Parsing tables...
# INFO: Parsing tables... [astroquery.utils.tap.core]
# 2026-02-23 14:27:14 INFO     Done.
# INFO: Done. [astroquery.utils.tap.core]
#
# [DEMO WARNING:] Naked eye stars do not have photometry besides g band
# TO DO: Make stamps with a more reasonable size. Dim stars can have smaller PSFs.
# To do this, make a profile of the Roman / PSF, and find out when would it be essentially 0.
# We might need to get rid of stars very far away.
# [ 69.39164    100.38605     68.24332    ... 123.24616811 124.03606251
#  122.90162923]
# (199028,)
# 100%|██████████| 199028/199028 [00:01<00:00, 136601.41it/s]
# 100%|██████████| 18/18 [05:51<00:00, 19.50s/it]
#   0%|          | 0/18 [00:00<?, ?it/s]2026-02-23 14:37:30 INFO     Broadcasting is not being used
# 2026-02-23 14:37:30 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:37:30 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:37:31 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmp_v3m9j5d/feb230e1-786f-4805-b82a-d751f867129a.zarr
# 2026-02-23 14:37:53 INFO     Copying output zarr array into output Numpy arrays
#   6%|▌         | 1/18 [00:25<07:12, 25.44s/it]2026-02-23 14:37:56 INFO     Broadcasting is not being used
# 2026-02-23 14:37:56 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:37:56 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:37:56 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmp915t5lqm/a4f45d85-e6fa-4f5c-b4df-a9b51e0258f3.zarr
# 2026-02-23 14:38:11 INFO     Copying output zarr array into output Numpy arrays
#  11%|█         | 2/18 [00:43<05:33, 20.85s/it]2026-02-23 14:38:14 INFO     Broadcasting is not being used
# 2026-02-23 14:38:14 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:38:14 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:38:14 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpfjwour3g/a57aca40-7802-4b27-9566-d36c838d7582.zarr
# 2026-02-23 14:38:29 INFO     Copying output zarr array into output Numpy arrays
#  17%|█▋        | 3/18 [01:00<04:50, 19.37s/it]2026-02-23 14:38:31 INFO     Broadcasting is not being used
# 2026-02-23 14:38:31 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:38:31 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:38:31 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpzruo3vdj/e509ea04-fedd-45b8-b8da-bcbcf62e2601.zarr
# 2026-02-23 14:38:45 INFO     Copying output zarr array into output Numpy arrays
#  22%|██▏       | 4/18 [01:17<04:15, 18.28s/it]2026-02-23 14:38:48 INFO     Broadcasting is not being used
# 2026-02-23 14:38:48 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:38:48 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:38:48 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmp85af91ug/d5f45d51-309d-4271-9314-0cc6b2dae559.zarr
# 2026-02-23 14:39:02 INFO     Copying output zarr array into output Numpy arrays
#  28%|██▊       | 5/18 [01:33<03:48, 17.54s/it]2026-02-23 14:39:04 INFO     Broadcasting is not being used
# 2026-02-23 14:39:04 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:39:04 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:39:04 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpk6hrtb7j/dc80104d-ee2b-48d4-b4fe-e09b090d27b8.zarr
# 2026-02-23 14:39:21 INFO     Copying output zarr array into output Numpy arrays
#  33%|███▎      | 6/18 [01:52<03:38, 18.18s/it]2026-02-23 14:39:23 INFO     Broadcasting is not being used
# 2026-02-23 14:39:23 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:39:23 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:39:24 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpcb0cev6v/fdc4a60d-3416-4873-baf8-3e46f2b9f9ef.zarr
# 2026-02-23 14:39:42 INFO     Copying output zarr array into output Numpy arrays
#  39%|███▉      | 7/18 [02:13<03:28, 18.95s/it]2026-02-23 14:39:44 INFO     Broadcasting is not being used
# 2026-02-23 14:39:44 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:39:44 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:39:44 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpd84m1q2v/cc48d9e8-d82f-4473-b220-285033f78678.zarr
# 2026-02-23 14:40:02 INFO     Copying output zarr array into output Numpy arrays
#  44%|████▍     | 8/18 [02:33<03:14, 19.40s/it]2026-02-23 14:40:04 INFO     Broadcasting is not being used
# 2026-02-23 14:40:04 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:40:04 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:40:04 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpblkv03as/3e023a5d-70ab-4376-ae0e-8e0d5c1e73b8.zarr
# 2026-02-23 14:40:21 INFO     Copying output zarr array into output Numpy arrays
#  50%|█████     | 9/18 [02:53<02:53, 19.33s/it]2026-02-23 14:40:24 INFO     Broadcasting is not being used
# 2026-02-23 14:40:24 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:40:24 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:40:24 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmps7jpks3s/68aedbe7-cc8f-4424-9285-d61a822a0125.zarr
# 2026-02-23 14:40:44 INFO     Copying output zarr array into output Numpy arrays
#  56%|█████▌    | 10/18 [03:16<02:44, 20.57s/it]2026-02-23 14:40:47 INFO     Broadcasting is not being used
# 2026-02-23 14:40:47 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:40:47 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:40:47 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpotyrluj7/5e515cb2-132d-4b6b-9dea-6eb5e76f7c81.zarr
# 2026-02-23 14:41:01 INFO     Copying output zarr array into output Numpy arrays
#  61%|██████    | 11/18 [03:32<02:14, 19.23s/it]2026-02-23 14:41:03 INFO     Broadcasting is not being used
# 2026-02-23 14:41:03 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:41:03 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:41:03 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpnrsowxsi/d3697f95-20b8-4c60-b29b-04068d75e854.zarr
# 2026-02-23 14:41:21 INFO     Copying output zarr array into output Numpy arrays
#  67%|██████▋   | 12/18 [03:52<01:57, 19.51s/it]2026-02-23 14:41:23 INFO     Broadcasting is not being used
# 2026-02-23 14:41:23 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:41:23 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:41:23 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmppkpiqeta/62cd35d0-64cf-4beb-ac00-45a577a67e6b.zarr
# 2026-02-23 14:41:40 INFO     Copying output zarr array into output Numpy arrays
#  72%|███████▏  | 13/18 [04:12<01:37, 19.56s/it]2026-02-23 14:41:43 INFO     Broadcasting is not being used
# 2026-02-23 14:41:43 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:41:43 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:41:43 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmp506mo192/d3cec789-9cda-41d5-857f-4ab92361bcdc.zarr
# 2026-02-23 14:42:00 INFO     Copying output zarr array into output Numpy arrays
#  78%|███████▊  | 14/18 [04:32<01:18, 19.60s/it]2026-02-23 14:42:03 INFO     Broadcasting is not being used
# 2026-02-23 14:42:03 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:42:03 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:42:03 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpt26yxwm2/2dd65169-196a-47ce-af16-5d3fcd053dcf.zarr
# 2026-02-23 14:42:17 INFO     Copying output zarr array into output Numpy arrays
#  83%|████████▎ | 15/18 [04:49<00:56, 18.80s/it]2026-02-23 14:42:20 INFO     Broadcasting is not being used
# 2026-02-23 14:42:20 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:42:20 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:42:20 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpjgu1e_wg/68a3da37-1f88-43f3-928f-a7bf028dd0c6.zarr
# 2026-02-23 14:42:38 INFO     Copying output zarr array into output Numpy arrays
#  89%|████████▉ | 16/18 [05:09<00:38, 19.33s/it]2026-02-23 14:42:40 INFO     Broadcasting is not being used
# 2026-02-23 14:42:40 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:42:40 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:42:40 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpks_mkezv/657edefc-f32b-4ce6-9287-f7fc66a8ac68.zarr
# 2026-02-23 14:42:57 INFO     Copying output zarr array into output Numpy arrays
#  94%|█████████▍| 17/18 [05:29<00:19, 19.36s/it]2026-02-23 14:43:00 INFO     Broadcasting is not being used
# 2026-02-23 14:43:00 INFO     Not parallelizing along broadcasted dimension (block_size=None, shape_out=(4088, 4088))
# 2026-02-23 14:43:00 INFO     Setting up output dask array with map_blocks
# 2026-02-23 14:43:00 INFO     Computing output array directly to zarr array at /var/folders/s4/f7nrp0c95f5ccmwc7csdxt5r0000gq/T/tmpl0_q8z9k/5858618e-db10-4146-b91b-98d7ea944d0e.zarr
# 2026-02-23 14:43:14 INFO     Copying output zarr array into output Numpy arrays
# 100%|██████████| 18/18 [05:45<00:00, 19.21s/it]

# %%
rosalia_psf
# Out:
# '/Users/aborlaff/NASA/ROSALIA/notebooks/WFI_F129_RA_123.000_DEC_023.000_MJD_60462.00000_PA_045.00_stars.fits'
