# %% [markdown]
# # Using ROSALIA to find asteroids in WFI exposures

# %% [markdown]
# ***

# %% [markdown]
# ## What is this?
#
# `ROSALIA` allows the user to estimate much more than stray-light on Roman WFI exposures. In this notebook, we will demonstrate how to use of ROSALIA to find out which Solar System Objects are in your Roman datasets. Following the previous tutorial, we will use datasets stored in the Roman Nexus cloud. We will access a pre-generated Roman mock observation, generate a ROSALIA exposure object, and then use the `rosalia.core.exposure.get_nearby_ssos()` method to automatically query and propagate the orbits of known Solar System Objects stored in the Minor Planet Center database.
#
#
# Additional information about ROSALIA can be found in the [ROSALIA for Roman documentation](https://rosalia.readthedocs.io/en/latest/) article on ReadTheDocs.
#
# ## How to start
#
# To run this notebook, please activate the "rosalia" kernel at the top right of your window.
#
# ## Imports
#
# - *rosalia* for Roman/WFI stray-light analysis
# - *matplotlib* for plotting the results.

# %%
! pwd
# Out:
# /Users/aborlaff/NASA/ROSALIA/notebooks/tutorials

# %%
# %matplotlib inline
import rosalia as rs

# %% [markdown]
# ## Quick start

# %% [markdown]
# First we select a Roman mock image stored at the S3 bucket in Nexus. We generate a ROSALIA exposure object by using rosalia.core.exposure. ROSALIA will automatically detect that the path is a Nexus S3 file, but it also works with local fits or asdf files.

# %%
# With this line we generate the exposure object. This is the first step in any ROSALIA analysis. 
asdf_dir_uri = "s3://stpubdata/roman/nexus/soc_simulations/tutorial_data/roman-2026.2/"
input_name = asdf_dir_uri + 'r0003201001001001004_0004_wfi*_f106_cal.asdf' 

rosalia_exposure = rs.core.exposure(filename=input_name)
# Out:
# 100%|██████████| 18/18 [20:04<00:00, 66.92s/it]

# %% [markdown]
# The `rosalia_exposure` object contains all the necessary information about this particular exposure. It takes a few seconds to run, but it will provide a lot of info in an easy way. You can try to print some useful quantities below.

# %% [markdown]
# To estimate the locations of the SSOs, ROSALIA uses another package built by our team named `EPHESSOS` (https://pypi.org/project/ephessos/). `EPHESSOS` automatically queries orbital parameters from the Minor Planet Center database (https://www.minorplanetcenter.net/iau/mpc.html), and propagates the orbits through JPL/Horizons, returning the expected trajectory along the duration of the Roman / WFI exposure. All this happens in the background after using the `rosalia_exposure.get_nearby_ssos()` method.

# %%
# Here we execute the Solar System Object query method to estimate the trajectories of known SSOs. 
cone_search, ephessos_df = rosalia_exposure.get_nearby_ssos()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Here we execute the Solar System Object query method to estimate the trajectories of known SSOs.
# ----> 2 cone_search, ephessos_df = rosalia_exposure.get_nearby_ssos()
#
# File ~/NASA/ROSALIA/rosalia/core.py:376, in exposure.get_nearby_ssos(self, ra, dec, radius, mjd, verbose, time_step)
#     374     return()
#     375 else:
# --> 376     ephessos_df = ep.core.ephessos(sso_search=cone_search, mjd_start=self.EXPSTART, mjd_end=self.EXPEND,
#     377                                    obs_center=self.JPL_OBSLOC, step_size=time_step, verbose=verbose)
#     378 return(cone_search, ephessos_df)
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/ephessos/core.py:99, in ephessos(sso_search, mpc_table, designation, name, mode, epoch, eccentricity, perihelion_distance, perihelion_date, node, arg_perihelion, inclination, mean_anomaly, semimajor_axis, mean_motion, H_mag, G_slope, obs_center, mjd_start, mjd_end, step_size, quantities, verbose)
#      96     name = sso_search.iloc[i]['Name']
#      97     epoch = Time(sso_search.iloc[i]['epoch'], format="jd").isot
# ---> 99     ephessos_df = ep.core.ephessos(designation=name, mode=mode, epoch=epoch,
#     100                                    obs_center=obs_center,
#     101                                    mjd_start=mjd_start, mjd_end=mjd_end,
#     102                                    step_size=step_size,
#     103                                    quantities=quantities, verbose=verbose)
#     105     ephessos_df_list.append(ephessos_df)
#     106 return(ephessos_df_list)
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/ephessos/core.py:110, in ephessos(sso_search, mpc_table, designation, name, mode, epoch, eccentricity, perihelion_distance, perihelion_date, node, arg_perihelion, inclination, mean_anomaly, semimajor_axis, mean_motion, H_mag, G_slope, obs_center, mjd_start, mjd_end, step_size, quantities, verbose)
#     106         return(ephessos_df_list)
#     109 if sso_search is None:
# --> 110     ephessos_out = _ephessos(designation=designation, mode=mode, epoch=epoch,
#     111                              eccentricity=eccentricity, perihelion_distance=perihelion_distance,
#     112                              perihelion_date=perihelion_date, node=node,
#     113                              arg_perihelion=arg_perihelion, inclination=inclination,
#     114                              mean_anomaly=mean_anomaly, semimajor_axis=semimajor_axis,
#     115                              mean_motion=mean_motion,
#     116                              H_mag=H_mag, G_slope=G_slope,
#     117                              obs_center=obs_center, mjd_start=mjd_start, mjd_end=mjd_end,
#     118                              step_size=step_size, quantities=quantities, verbose=verbose)
#     119     return(ephessos_out)
#
# File ~/miniforge3/envs/rosalia/lib/python3.12/site-packages/ephessos/core.py:235, in _ephessos(designation, mode, epoch, eccentricity, perihelion_distance, perihelion_date, node, arg_perihelion, inclination, mean_anomaly, semimajor_axis, mean_motion, H_mag, G_slope, obs_center, mjd_start, mjd_end, step_size, quantities, verbose)
#     233 lines_horizons_query = np.array(mystr.split('\n'))
#     234 if verbose: print(lines_horizons_query)
# --> 235 id_start_of_table = np.where(lines_horizons_query == '$$SOE')[0][0]
#     236 id_end_of_table = np.where(lines_horizons_query == '$$EOE')[0][0]
#     237 id_column_names = id_start_of_table - 2
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import matplotlib.pyplot as plt 
ax = rosalia_exposure.plot_footprint(figsize=(8,5))
for i in range(len(ephessos_df)):
    # print(ephessos_df[i]["Designation"][0])
    ax.plot(ephessos_df[i]["RA_deg_ICRF"], ephessos_df[i]["DEC_deg_ICRF"], label=ephessos_df[i]["Designation"].iloc[0])
    ax.legend(frameon=False, loc='center left', bbox_to_anchor=(1, 0.5), ncol=3)
ax.xaxis.set_inverted(True) 
plt.savefig("SSOs_in_Roman_WFI_exposure.png", dpi=300)
plt.show()

# %% [markdown]
# ## About this Notebook
#
# **Author:** Alejandro S. Borlaff - NASA Ames Research Center (Code S) - a.s.borlaff@nasa.gov
#
# **Updated on** July 28, 2026.

# %% [markdown]
# <table width="100%" style="border:none; border-collapse:collapse;">
#
#   <tr style="border:none;">
#     <td style="border:none; width:180px; white-space:nowrap;">
#        <a href="#top" style="text-decoration:none; color:#0066cc;"> Top of page</a>
#     </td>
#     <td style="border:none; text-align:center;">
#         <img src="https://raw.githubusercontent.com/spacetelescope/roman_notebooks/refs/heads/main/roman_logo.png" alt="roman_logo" width="50px">
#     </td>
#     <td style="border:none; text-align:right;">
#        <img src="https://raw.githubusercontent.com/spacetelescope/roman_notebooks/refs/heads/main/stsci_logo2.png" width="90">
#     </td>
#   </tr>
# </table>
